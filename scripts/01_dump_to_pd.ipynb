# %%
## Bibliotheken:
from bs4 import BeautifulSoup
from lxml import etree as ET
import pandas as pd
import unicodedata
from tqdm import tqdm
import polars as pl

# %%
#Einlesen des Dumps in ElementTree:

xml = open("ohs_03_2024.xml", "r", encoding="utf-8")
tree = ET.parse(xml) 
root = tree.getroot() 

records = list(root)
total_records = len(records)  

#Ausgabe der Gesamtzahl der in der Datei vorhandenen Records:
print("Gesamtzahl bibliographischer Einträge: ",total_records)
# Out:
# Gesamtzahl bibliographischer Einträge:  325358

# %%
#Function to get actual data: 
def parse_record(xml):
      
    ns = {"marc":"http://www.loc.gov/MARC21/slim"}
        
    #IDN:      
    idn = xml.findall("marc:controlfield[@tag = '001']", namespaces=ns)
    try:
        idn = idn[0].text
    except:
        idn = 'fail'
        
    #008:      
    c008 = xml.findall("marc:controlfield[@tag = '008']", namespaces=ns)
    try:
        c008 = c008[0].text
    except:
        c008 = 'fail'
        
        
    #Language: 
    lang = xml.findall("marc:datafield[@tag = '041']/marc:subfield[@code = 'a']", namespaces=ns)
    try:
        lang = lang[0].text
    except:
        lang = 'fail'
        
    #Creator: 
    creator = xml.findall("marc:datafield[@tag = '100']/marc:subfield[@code = 'a']", namespaces=ns)
    creator_body = xml.findall("marc:datafield[@tag = '110']/marc:subfield[@code = 'a']", namespaces=ns)
    if creator:
        creator = creator[0].text
    elif creator_body:
        creator = creator_body[0].text
    else:
        creator = "fail"    
        
        
    #Title: 
    maintitle = xml.findall("marc:datafield[@tag = '245']/marc:subfield[@code = 'a']", namespaces=ns)
    subtitle = xml.findall("marc:datafield[@tag = '245']/marc:subfield[@code = 'b']", namespaces=ns)
    if maintitle:
        maintitle = maintitle[0].text
        if subtitle: 
            title = maintitle + " : " + subtitle[0].text
        else:
            title = maintitle
    else:
        title = "fail"    
    
    
    #Place of publication: 
    place = xml.findall("marc:datafield[@tag = '264']/marc:subfield[@code = 'a']", namespaces=ns)
    diss = xml.findall("marc:datafield[@tag = '502']/marc:subfield[@code = 'a']", namespaces=ns)
    diss2 = xml.findall("marc:datafield[@tag = '502']/marc:subfield[@code = 'c']", namespaces=ns)
    if place:
        place = place[0].text
    elif diss:
        place = diss[0].text
    elif diss2:
        place = diss2[0].text
    else:
        place = "N/A"    
        
        
    #Year of publication: 
    year = xml.findall("marc:datafield[@tag = '264']/marc:subfield[@code = 'c']", namespaces=ns)
    diss = xml.findall("marc:datafield[@tag = '502']/marc:subfield[@code = 'a']", namespaces=ns)
    c008_2 = xml.findall("marc:controlfield[@tag = '008']", namespaces=ns)
    if year:
        year = year[0].text
    elif diss:
        year = diss[0].text
    elif c008_2:
        year = c008_2[0].text
        year = year[7:11] + " - 008"
    else:
        year = "0"    
    
         
    #notes: 
    notes = xml.findall("marc:datafield[@tag = '500']/marc:subfield[@code = 'a']", namespaces=ns)
    if notes:
        notes = notes[0].text
    else:
        notes = "N/A" 
    
    #diss: 
    diss0 = xml.findall("marc:datafield[@tag = '502']/marc:subfield[@code = 'a']", namespaces=ns)
    diss1 = xml.findall("marc:datafield[@tag = '502']/marc:subfield[@code = 'b']", namespaces=ns) #Diss
    diss2 = xml.findall("marc:datafield[@tag = '502']/marc:subfield[@code = 'c']", namespaces=ns) #Uni
    diss3 = xml.findall("marc:datafield[@tag = '502']/marc:subfield[@code = 'd']", namespaces=ns) #Jahr
    if diss0:
        diss0 = diss[0].text
    else:
        diss0 = "none"
        
    if diss1:
        dissdiss = diss1[0].text
    else:
        dissdiss = "none"  
        
    if diss2:
        dissuni = diss2[0].text
    else:
        dissuni = "none"   
    
    if diss3:
        dissyear = diss3[0].text
    else:
        dissyear = "none"  
         
    
    if diss0 != "none": 
        diss = diss0
    elif (dissdiss != "none") & (dissuni != "none") & (dissyear != "none"):
        diss = dissdiss + " " + dissuni + " " + dissyear
    elif (dissdiss != "none") & (dissuni != "none"):
        diss = dissdiss + " " + dissuni
    elif dissdiss != "none":
        diss = dissdiss
    else:
        diss = "not found"   
    
    #DDC: 
    ddc3 = xml.findall("marc:datafield[@tag = '082']/marc:subfield[@code = 'a']", namespaces=ns)
    if ddc3:
        ddc3 = ddc3[0].text
    else:
        ddc3 = "N/A"   
        
        
    #DDC weitere: 
    ddc1 = xml.findall("marc:datafield[@tag = '083']/marc:subfield[@code = 'a']", namespaces=ns)
    if ddc1:
        ddc1 = ddc1[0].text
    else:
        ddc1 = "N/A" 
        
        
    #DDC?: 
    ddc2 = xml.findall("marc:datafield[@tag = '083']/marc:subfield[@code = 'q']", namespaces=ns)
    if ddc2:
        ddc2 = ddc2[0].text
    else:
        ddc2 = "N/A" 
    
 
    #ddc_prio
    if ddc1: 
        ddc_prio = ddc1
    elif ddc2:
        ddc_prio = ddc2
    elif ddc3:
        ddc_prio = ddc3
    else:
        ddc_prio = "fail"
        

    #Sachgruppe: 
    sw = xml.findall("marc:datafield[@tag = '084']/marc:subfield[@code = 'a']", namespaces=ns)
    if sw:
        sw = sw[0].text
    else:
        sw = "N/A"    
        
    
    #Zusammenführen:
    gathered = {'ID':idn, 'Creator':creator, 'Title':title, 'lang':lang, 'Place':place, "Year": year, 'DDC':ddc_prio, 'DDC1':ddc1, 'DDC2':ddc2, 
                'DDC-DE?':ddc3, 'Sachgruppe':sw, 'diss':diss, 'notes':notes, '008':c008}
    return gathered

# %%
#extract relevant data for app from dump: 

pbar = tqdm(total=total_records)

result = []
for item in records:
    result.append(parse_record(item))
    pbar.update()
# Out:
#   2%|█▍                                                                         | 6297/325358 [00:28<23:50, 223.08it/s]
# 100%|█████████████████████████████████████████████████████████████████████████| 325358/325358 [10:07<00:00, 503.07it/s]

# %%
#Convert to Dataframe and save as .h5: 

#df = pl.DataFrame(result)
#df.write_parquet("data/online_diss_03-2024.parquet")
df = pd.DataFrame(result)
df.to_hdf('data/online_diss_03-2024.h5', key='df')
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[20], line 6
#       1 #Convert to Dataframe and save as .h5:
#       2
#       3 #df = pl.DataFrame(result)
#       4 #df.write_parquet("data/online_diss_03-2024.parquet")
#       5 df = pd.DataFrame(result)
# ----> 6 df.to_hdf('data/online_diss_03-2024.h5', key='df')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:2779, in NDFrame.to_hdf(self, path_or_buf, key, mode, complevel, complib, append, format, index, min_itemsize, nan_rep, dropna, data_columns, errors, encoding)
#    2775 from pandas.io import pytables
#    2777 # Argument 3 to "to_hdf" has incompatible type "NDFrame"; expected
#    2778 # "Union[DataFrame, Series]" [arg-type]
# -> 2779 pytables.to_hdf(
#    2780     path_or_buf,
#    2781     key,
#    2782     self,  # type: ignore[arg-type]
#    2783     mode=mode,
#    2784     complevel=complevel,
#    2785     complib=complib,
#    2786     append=append,
#    2787     format=format,
#    2788     index=index,
#    2789     min_itemsize=min_itemsize,
#    2790     nan_rep=nan_rep,
#    2791     dropna=dropna,
#    2792     data_columns=data_columns,
#    2793     errors=errors,
#    2794     encoding=encoding,
#    2795 )
#
# File ~\anaconda3\Lib\site-packages\pandas\io\pytables.py:310, in to_hdf(path_or_buf, key, value, mode, complevel, complib, append, format, index, min_itemsize, nan_rep, dropna, data_columns, errors, encoding)
#     306 if isinstance(path_or_buf, str):
#     307     with HDFStore(
#     308         path_or_buf, mode=mode, complevel=complevel, complib=complib
#     309     ) as store:
# --> 310         f(store)
#     311 else:
#     312     f(path_or_buf)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\pytables.py:292, in to_hdf.<locals>.<lambda>(store)
#     278     f = lambda store: store.append(
#     279         key,
#     280         value,
#    (...)
#     288         encoding=encoding,
#     289     )
#     290 else:
#     291     # NB: dropna is not passed to `put`
# --> 292     f = lambda store: store.put(
#     293         key,
#     294         value,
#     295         format=format,
#     296         index=index,
#     297         min_itemsize=min_itemsize,
#     298         nan_rep=nan_rep,
#     299         data_columns=data_columns,
#     300         errors=errors,
#     301         encoding=encoding,
#     302         dropna=dropna,
#     303     )
#     305 path_or_buf = stringify_path(path_or_buf)
#     306 if isinstance(path_or_buf, str):
#
# File ~\anaconda3\Lib\site-packages\pandas\io\pytables.py:1159, in HDFStore.put(self, key, value, format, index, append, complib, complevel, min_itemsize, nan_rep, data_columns, encoding, errors, track_times, dropna)
#    1157     format = get_option("io.hdf.default_format") or "fixed"
#    1158 format = self._validate_format(format)
# -> 1159 self._write_to_group(
#    1160     key,
#    1161     value,
#    1162     format=format,
#    1163     index=index,
#    1164     append=append,
#    1165     complib=complib,
#    1166     complevel=complevel,
#    1167     min_itemsize=min_itemsize,
#    1168     nan_rep=nan_rep,
#    1169     data_columns=data_columns,
#    1170     encoding=encoding,
#    1171     errors=errors,
#    1172     track_times=track_times,
#    1173     dropna=dropna,
#    1174 )
#
# File ~\anaconda3\Lib\site-packages\pandas\io\pytables.py:1857, in HDFStore._write_to_group(self, key, value, format, axes, index, append, complib, complevel, fletcher32, min_itemsize, chunksize, expectedrows, dropna, nan_rep, data_columns, encoding, errors, track_times)
#    1854     raise ValueError("Compression not supported on Fixed format stores")
#    1856 # write the object
# -> 1857 s.write(
#    1858     obj=value,
#    1859     axes=axes,
#    1860     append=append,
#    1861     complib=complib,
#    1862     complevel=complevel,
#    1863     fletcher32=fletcher32,
#    1864     min_itemsize=min_itemsize,
#    1865     chunksize=chunksize,
#    1866     expectedrows=expectedrows,
#    1867     dropna=dropna,
#    1868     nan_rep=nan_rep,
#    1869     data_columns=data_columns,
#    1870     track_times=track_times,
#    1871 )
#    1873 if isinstance(s, Table) and index:
#    1874     s.create_index(columns=index)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\pytables.py:3328, in BlockManagerFixed.write(self, obj, **kwargs)
#    3325 for i, blk in enumerate(data.blocks):
#    3326     # I have no idea why, but writing values before items fixed #2299
#    3327     blk_items = data.items.take(blk.mgr_locs)
# -> 3328     self.write_array(f"block{i}_values", blk.values, items=blk_items)
#    3329     self.write_index(f"block{i}_items", blk_items)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\pytables.py:3169, in GenericFixed.write_array(self, key, obj, items)
#    3166         warnings.warn(ws, PerformanceWarning, stacklevel=find_stack_level())
#    3168     vlarr = self._handle.create_vlarray(self.group, key, _tables().ObjectAtom())
# -> 3169     vlarr.append(value)
#    3171 elif lib.is_np_dtype(value.dtype, "M"):
#    3172     self._handle.create_array(self.group, key, value.view("i8"))
#
# File ~\anaconda3\Lib\site-packages\tables\vlarray.py:510, in VLArray.append(self, sequence)
#     508 atom = self.atom
#     509 if not hasattr(atom, 'size'):  # it is a pseudo-atom
# --> 510     sequence = atom.toarray(sequence)
#     511     statom = atom.base
#     512 else:
#
# File ~\anaconda3\Lib\site-packages\tables\atom.py:1040, in _BufferedAtom.toarray(self, object_)
#    1039 def toarray(self, object_):
# -> 1040     buffer_ = self._tobuffer(object_)
#    1041     array = np.ndarray(buffer=buffer_, dtype=self.base.dtype,
#    1042                        shape=len(buffer_))
#    1043     return array
#
# File ~\anaconda3\Lib\site-packages\tables\atom.py:1173, in ObjectAtom._tobuffer(self, object_)
#    1172 def _tobuffer(self, object_):
# -> 1173     return pickle.dumps(object_, pickle.HIGHEST_PROTOCOL)
#
# MemoryError:

# %%
df
# Out:
# shape: (325_358, 14)
# ┌───────────┬────────────────┬────────────────┬──────┬───┬────────────┬────────────────┬───────────────┬───────────────┐
# │ ID        ┆ Creator        ┆ Title          ┆ lang ┆ … ┆ Sachgruppe ┆ diss           ┆ notes         ┆ 008           │
# │ ---       ┆ ---            ┆ ---            ┆ ---  ┆   ┆ ---        ┆ ---            ┆ ---           ┆ ---           │
# │ str       ┆ str            ┆ str            ┆ str  ┆   ┆ str        ┆ str            ┆ str           ┆ str           │
# ╞═══════════╪════════════════╪════════════════╪══════╪═══╪════════════╪════════════════╪═══════════════╪═══════════════╡
# │ 010063374 ┆ fail           ┆ Veröffentlichu ┆ ger  ┆ … ┆ N/A        ┆ not found      ┆ Digital.:     ┆ 991118d191219 │
# │           ┆                ┆ ngen aus dem   ┆      ┆   ┆            ┆                ┆ Frankfurt, M. ┆ 36xx u||m|    │
# │           ┆                ┆ Ge…            ┆      ┆   ┆            ┆                ┆ : Univ…       ┆ ||| 0…        │
# │ 010081208 ┆ fail           ┆ Gewässerschutz ┆ ger  ┆ … ┆ N/A        ┆ not found      ┆ Ersch. teils  ┆ 991118c196899 │
# │           ┆                ┆ , Wasser,      ┆      ┆   ┆            ┆                ┆ auch als      ┆ 99gw z||m|    │
# │           ┆                ┆ Abwas…         ┆      ┆   ┆            ┆                ┆ CD-ROM-A…     ┆ ||| 0…        │
# │ 010251928 ┆ fail           ┆ Regionale Schu ┆ ger  ┆ … ┆ N/A        ┆ not found      ┆ Ersch. teils  ┆ 991118c198899 │
# │           ┆                ┆ lgeschichte :  ┆      ┆   ┆            ┆                ┆ auch als      ┆ 99gw z||m|    │
# │           ┆                ┆ Sc…            ┆      ┆   ┆            ┆                ┆ Online-A…     ┆ ||| 0…        │
# │ 010409254 ┆ Universität    ┆ Berichte aus   ┆ ger  ┆ … ┆ N/A        ┆ not found      ┆ N/A           ┆ 991118c198299 │
# │           ┆ Stuttgart      ┆ dem Institut   ┆      ┆   ┆            ┆                ┆               ┆ 99gw z||m|    │
# │           ┆                ┆ für…           ┆      ┆   ┆            ┆                ┆               ┆ ||| 0…        │
# │ 010446613 ┆ Verein         ┆ Fortschrittber ┆ ger  ┆ … ┆ N/A        ┆ not found      ┆ N/A           ┆ 991118c198599 │
# │           ┆ Deutscher      ┆ ichte VDI      ┆      ┆   ┆            ┆                ┆               ┆ 99gw z||m|    │
# │           ┆ Ingenieure     ┆                ┆      ┆   ┆            ┆                ┆               ┆ ||| 0…        │
# │ …         ┆ …              ┆ …              ┆ …    ┆ … ┆ …          ┆ …              ┆ …             ┆ …             │
# │ 999997297 ┆ Moschkau,      ┆ Defektabhängig ┆ ger  ┆ … ┆ N/A        ┆ Göttingen,     ┆ N/A           ┆ 100204s2009   │
# │           ┆ Peter          ┆ e              ┆      ┆   ┆            ┆ Univ., Diss.,  ┆               ┆ gw |||||om||| │
# │           ┆                ┆ Transporteige… ┆      ┆   ┆            ┆ 2009           ┆               ┆ 0…            │
# │ 999997505 ┆ Scheler,       ┆ Tailoring      ┆ eng  ┆ … ┆ VN 5927    ┆ Bayreuth,      ┆ N/A           ┆ 100204s2009   │
# │           ┆ Esther         ┆ fluorene-based ┆      ┆   ┆            ┆ Univ., Diss.,  ┆               ┆ gw |||||om||| │
# │           ┆                ┆ oligo…         ┆      ┆   ┆            ┆ 2009           ┆               ┆ 0…            │
# │ 99999767X ┆ Körzdörfer,    ┆ Self-interacti ┆ eng  ┆ … ┆ UM 1200    ┆ Bayreuth,      ┆ Enth. 4       ┆ 100204s2009   │
# │           ┆ Thomas         ┆ on and charge  ┆      ┆   ┆            ┆ Univ., Diss.,  ┆ Sonderabdr.   ┆ gw |||||om||| │
# │           ┆                ┆ tr…            ┆      ┆   ┆            ┆ 2009           ┆ aus versch…   ┆ 0…            │
# │ 999999389 ┆ Xystrakis,     ┆ The drought    ┆ eng  ┆ … ┆ N/A        ┆ Freiburg       ┆ Dateien in    ┆ 100204s2009   │
# │           ┆ Fotios         ┆ tolerance      ┆      ┆   ┆            ┆ (Breisgau),    ┆ unterschiedli ┆ gw |||||om||| │
# │           ┆                ┆ limit …        ┆      ┆   ┆            ┆ Univ., Di…     ┆ chen F…       ┆ 0…            │
# │ 999999540 ┆ Hübner, Sandra ┆ Learning       ┆ eng  ┆ … ┆ N/A        ┆ Freiburg       ┆ N/A           ┆ 100204s2009   │
# │           ┆                ┆ journals as    ┆      ┆   ┆            ┆ (Breisgau),    ┆               ┆ gw |||||om||| │
# │           ┆                ┆ medium of…     ┆      ┆   ┆            ┆ Univ., Di…     ┆               ┆ 0…            │
# └───────────┴────────────────┴────────────────┴──────┴───┴────────────┴────────────────┴───────────────┴───────────────┘
